# %% [markdown]
# Leitura dos dados

# %%
import pandas as pd

# %%
df = pd.read_csv("student_scores.csv")

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
df.isna().any()
# Out:
# Hours     False
# Scores    False
# dtype: bool

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.dpi"]=200
plt.scatter(df["Hours"], df["Scores"])
plt.title("Hours vs Score")
plt.xlabel("Hours Studied")
plt.ylabel("Percent Score")
plt.show()

# %%
import numpy as np

data_x= np.array(df["Hours"]).reshape(-1, 1)
data_y= np.array(df["Scores"]).reshape(-1, 1)

# %% [markdown]
# Divisão dos dados para teste e treino

# %%
from sklearn.model_selection import train_test_split
x_treino, x_teste , y_treino , y_teste =  train_test_split(data_x, data_y, test_size=0.2)

# %%
print("Treino: ",len(x_treino))
print("Teste: ",len(x_teste))
# Out:
# Treino:  20
# Teste:  5

# %% [markdown]
# ##Criação dos Modelos

# %%
from sklearn import linear_model

modelo = linear_model.LinearRegression()
modelo.fit(x_treino, y_treino)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("Coeficiente ", modelo.coef_)
# Out:
# Coeficiente  [[9.72962279]]

# %% [markdown]
# ##Predicoes para o modelo

# %%
y_predicao = modelo.predict(x_teste)

# %%
plt.scatter(x_teste, x_teste, color="black")
plt.scatter(x_teste, y_predicao, color="red")
plt.plot(x_teste,y_predicao, color= "red")
plt.show()

# %% [markdown]
# Metrica de avaliacao

# %%
from sklearn.metrics import mean_squared_error

# %%
mse= mean_squared_error(y_teste, y_predicao)

# %%
print("MSE: ", mse)
# Out:
# MSE:  54.30591178321455

# %% [markdown]
# Prediçoes do Usuario

# %%
x=np.array([10]).reshape(-1,1)
nota= modelo.predict(x)

print(f"O aluno tera nota: {nota[0][0]}")
# Out:
# O aluno tera nota: 100.29537061461357
